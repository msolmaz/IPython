# %% [markdown]
# In this study, we will slice both d0Sig and LxySig axes to see how the shape of the distributions is affected by each cut value...

# %%
from math import sqrt
import ROOT
from ROOT import TFile, TDirectory, TH1F, TCanvas, TLegend, TLine, TText, TPad, TF1
import rootnotes
ROOT.gStyle.SetErrorX(0) #To remove horizontal bars...
#gStyle.SetTitleYSize(0.02)

# %% [markdown]
# d0Sig-> y<D0Sig where y = 0,1,2,3,4 (chosen manually) and x<LxySig<20 where x is incremented by 1... Note that the procedure is only applied to control region... By the way, number of bins is 20 for both axes and bin width is 1...

# %%
inputFileData = TFile.Open("/Users/melihsolmaz/Desktop/ipython/Data22Jan_combined_2saMu_April_25_Rebinning.root")
#nMinus1_looseCollCuts = inputFileData.Get("nMinus1_leptonD0Sig_vs_LxySig_looseCollCuts")
nMinus1_looseControlCollCuts = inputFileData.Get("nMinus1_leptonD0Sig_vs_LxySig_looseControlCollCuts")

#Define the function here....

def LxySig_distribution(y):
#    final_region_dist = ROOT.TH1F("final_region_"+str(y), "", 24, 0, 12)
    control_region_dist = ROOT.TH1F("control_region_"+str(y), "", 20, 0, 20)

#Some Histogram Settings
    control_region_dist.GetXaxis().SetTitle("L_{xy}/#sigma_{L_{xy}}")
    control_region_dist.GetYaxis().SetTitle("Number of events with L_{xy}/#sigma_{L_{xy}} > x ")
    control_region_dist.SetTitle("#scale[0.8]{CMS Preliminary #sqrt{s} = 8 TeV, L = 20.5 fb^{-1}}")

#    final_region_dist.SetStats(0)
    control_region_dist.SetStats(0)
#    final_region_dist.SetMarkerStyle(8)
    control_region_dist.SetMarkerStyle(21)
#    final_region_dist.SetMarkerColor(2)
    control_region_dist.SetMarkerColor(1)
#    final_region_dist.SetLineColor(2)
    control_region_dist.SetLineColor(1)
#    final_region_dist.Sumw2
    control_region_dist.Sumw2

    #control_region_dist.SetMaximum(400.0)


#nYbins= nMinus1_looseControlCollCuts.GetNbinsY()
#print "nYbins= ", nYbins

#nXbins= nMinus1_looseControlCollCuts.GetNbinsX()
#print "nXbins= ", nXbins

#Loop to write down new histos...

    for i in range(1,20):
#        if y == 0 :
#            final_region_dist.SetBinContent(i, nMinus1_looseCollCuts.Integral(2*y+1, 8, i, 12))
        control_region_dist.SetBinContent(i, nMinus1_looseControlCollCuts.Integral(y+1, 21, i, 21))
#        else :
#            final_region_dist.SetBinContent(i, nMinus1_looseCollCuts.Integral(2*y, 8, i, 12))
#            control_region_dist.SetBinContent(i, nMinus1_looseControlCollCuts.Integral(2*y, 41, i, 41))
            
# Legend
    leg = TLegend(0.6,0.6,0.85,0.85)
    leg.SetFillColor(0)
    leg.SetLineColor(0)
#    leg.AddEntry(final_region_dist, "Signal (|#Delta#Phi| < #pi/2)", "pl")
    leg.AddEntry(control_region_dist, "Control (|#Delta#Phi| > #pi/2)", "pl")

#Line
    line = TLine(12, 0, 12, 22)
    line.SetLineColor(4)
    line.SetLineStyle(2)

#Text
#    text = TText(7, 2, "Excluded Region")

#print "total number of entries = ", control_region_dist.GetEntries()    
    canvas=TCanvas("canvas_"+str(y),"", 800, 800)
    control_region_dist.Draw("e")
#    final_region_dist.Draw("esame")
    leg.Draw("same")
    line.Draw()
#    text.Draw()
    canvas.Draw()
    canvas.SetLogy(True)
    return canvas, leg, control_region_dist, line

# %% [markdown]
# d0Sig>0

# %%
result = LxySig_distribution(0)
result[0]
# Out:
# <ROOT.TCanvas object ("canvas_0") at 0x7fb067c5b630>

# %% [markdown]
# d0Sig>=1

# %%
result1 = LxySig_distribution(1)
result1[0]
# Out:
# <ROOT.TCanvas object ("canvas_1") at 0x7fb063a5eb10>

# %% [markdown]
# d0Sig >= 2

# %%
result2 = LxySig_distribution(2)
result2[0]
# Out:
# <ROOT.TCanvas object ("canvas_2") at 0x7fb067c706c0>

# %% [markdown]
# d0Sig >= 3

# %%
result3 = LxySig_distribution(3)
result3[0]
# Out:
# <ROOT.TCanvas object ("canvas_3") at 0x7fb065a13d90>

# %% [markdown]
# d0Sig >= 4

# %%
result4 = LxySig_distribution(4)
result4[0]
# Out:
# <ROOT.TCanvas object ("canvas_4") at 0x7fb063c23650>

# %% [markdown]
# Fit the data points for the histogram just above to estimate the background...

# %%
histo_control_bckg = result4[2]
#Define the function here...

func_fit = TF1("fit_function","[0]*exp([1]+[2]*x)", 0, 20)

canvas_fit = TCanvas("canvas_fit", "", 800, 800)
#control_region_dist.Fit("fit_function", "R")
histo_control_bckg.Fit("fit_function", "R")
histo_control_bckg.Draw("ep")
#func_fit.Draw()

#canvas_fit.Update()
canvas_fit.Draw()
canvas_fit
# Out:
# <ROOT.TCanvas object ("canvas_fit") at 0x7fb065a18120>

# %%
func_fit(12)
# Out:
# 1.0989051399808913

# %%
def d0Sig_distribution(y):
#    final_region_dist = ROOT.TH1F("final_region_"+str(y), "", 24, 0, 12)
    control_d0_region_dist = ROOT.TH1F("control_d0_region_"+str(y), "", 20, 0, 20)

#Some Histogram Settings
    control_d0_region_dist.GetXaxis().SetTitle("d_{0}/#sigma_{d_{0}}")
    control_d0_region_dist.GetYaxis().SetTitle("Number of events with d_{0}/#sigma_{d_{0}} > x ")
    control_d0_region_dist.SetTitle("#scale[0.8]{CMS Preliminary #sqrt{s} = 8 TeV, L = 20.5 fb^{-1}}")

#    final_region_dist.SetStats(0)
    control_d0_region_dist.SetStats(0)
#    final_region_dist.SetMarkerStyle(8)
    control_d0_region_dist.SetMarkerStyle(21)
#    final_region_dist.SetMarkerColor(2)
    control_d0_region_dist.SetMarkerColor(1)
#    final_region_dist.SetLineColor(2)
    control_d0_region_dist.SetLineColor(1)
#    final_region_dist.Sumw2
    control_d0_region_dist.Sumw2

    #control_region_dist.SetMaximum(400.0)


#nYbins= nMinus1_looseControlCollCuts.GetNbinsY()
#print "nYbins= ", nYbins

#nXbins= nMinus1_looseControlCollCuts.GetNbinsX()
#print "nXbins= ", nXbins

#Loop to write down new histos...

    for i in range(1,20):
#        if y == 0 :
#            final_region_dist.SetBinContent(i, nMinus1_looseCollCuts.Integral(2*y+1, 8, i, 12))
        control_d0_region_dist.SetBinContent(i, nMinus1_looseControlCollCuts.Integral(i, 21, y+1, 21))
#        else :
#            final_region_dist.SetBinContent(i, nMinus1_looseCollCuts.Integral(2*y, 8, i, 12))
#            control_region_dist.SetBinContent(i, nMinus1_looseControlCollCuts.Integral(2*y, 41, i, 41))
            
# Legend
    leg1 = TLegend(0.6,0.6,0.85,0.85)
    leg1.SetFillColor(0)
    leg1.SetLineColor(0)
#    leg.AddEntry(final_region_dist, "Signal (|#Delta#Phi| < #pi/2)", "pl")
    leg1.AddEntry(control_d0_region_dist, "Control (|#Delta#Phi| > #pi/2)", "pl")

#Line
    line1 = TLine(2, 0, 2, 22)
    line1.SetLineColor(4)
    line1.SetLineStyle(2)

#Text
#    text = TText(7, 2, "Excluded Region")

#print "total number of entries = ", control_region_dist.GetEntries()    
    canvas_d0=TCanvas("canvas_d0_"+str(y),"", 800, 800)
    control_d0_region_dist.Draw("e")
#    final_region_dist.Draw("esame")
    leg1.Draw("same")
    line1.Draw()
#    text.Draw()
    canvas_d0.Draw()
    canvas_d0.SetLogy(True)
    return canvas_d0, leg1, control_d0_region_dist, line1

# %% [markdown]
# LxySig>=12

# %%
result5 = d0Sig_distribution(12)
result5[0]
# Out:
# <ROOT.TCanvas object ("canvas_d0_12") at 0x7fb065a44100>

# %%
histo_d0_control_bckg = result5[2]
#Define the function here...

func_d0_fit = TF1("fit_d0_function","[0]*exp([1]+[2]*x)", 0, 20)

canvas_d0_fit = TCanvas("canvas_d0_fit", "", 800, 800)
#control_region_dist.Fit("fit_function", "R")
histo_d0_control_bckg.Fit("fit_d0_function", "R")
histo_d0_control_bckg.Draw("ep")
#func_fit.Draw()

#canvas_fit.Update()
canvas_d0_fit.Draw()
canvas_d0_fit
# Out:
# <ROOT.TCanvas object ("canvas_d0_fit") at 0x7fb065a476c0>

# %%
func_d0_fit(4)
# Out:
# 0.17678131864306978
